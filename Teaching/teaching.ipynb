# %% [markdown]
# # What is Jupyter
#
# Jupyter notebooks combine software code, computational output, explanatory text, and rich content in a single document. Notebooks allow in-browser editing and execution of code and display computation results. A notebook is saved with an .ipynb extension. The Jupyter Notebook project supports dozens of programming languages, its name reflecting support for Julia (Ju), Python (Py), and R.
#
#
# # What do I need to get started with Jupyter?
#
#
# The Jupyter Notebook project supports many programming languages. We’ll use IPython in this example. It uses the same syntax as Python but provides a more interactive experience. You’ll need the following Python libraries to do the mathematical computations needed for machine learning:
#
# - NumPy: For creating and manipulating vectors and matrices.
# - Pandas: For analyzing data and for data wrangling or munging. Pandas takes data such as a CSV file or a database, and creates from it a Python object called a DataFrame. A `DataFrame` is the central data structure in the Pandas API and is similar to a spreadsheet as follows:
#   - A `DataFrame` stores data in cells.
#   - A `DataFrame` has named columns (usually) and numbered rows.
# - Matplotlib: For visualizing data.
# - Sklern: For supervised and unsupervised learning. This library provides various tools for model fitting, data preprocessing, model selection, and model evaluation. It has built-in machine learning algorithms and models called estimators. Each estimator can be fitted to some data using its `fit` method.
#
#
# # What are we doing today?
#
# Workflow we will be following today
#
# ![workflow](https://developers.redhat.com/sites/default/files/blog/2021/03/Dzone_ML_flow1.png)
#
#
# First, get python installed.
#
# Then run `pip install pandas pyplot matplotlib sklearn`
#
# OR
#
# Go here to try [Jupyter](https://jupyter.org/try)
#
# Go here for the main repo for today: [Repo](https://github.com/gauravsingh-shadowhealth/AdventuresInMachineLearning)
#
#
# # MANUela Anomaly ML Model
#
# Goal: Build a machine lerning model that detects anomalies in sensor vibration data
#
# ![anomalies](https://raw.githubusercontent.com/sa-mw-dach/manuela/master/docs/images/manuela-anomalies.png)
#
# **Outline:**
#
# ### Read and preview the labeled data
# - Read data from disk
# - Preview the raw data
# - Visualize vibration and anomalies
#
# ### Data wrangling
# - Convert time series data into small episodes that can be used for supervised learning.
# - Explore the new data format
#
# ### Model training
# - Prepare the data for modeling, training and testing
# - Train and validate model
#
# ### Save the new model
# - Save model to disk
# - Commit and push to git
#
# ###  Model serving during runtime
# - View the warpper code for the model serving with Seldon

# %% [markdown]
# ## Read data from disk

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('raw-data.csv')
df['time'] = pd.to_datetime(df['ts'],unit='ms')
df.set_index('time', inplace=True)
df.drop(columns=['ts'], inplace=True)

# %% [markdown]
# ### Preview the raw data
# Quick view on the data. It is a dataframe with a
# - timeseries,
# - an id for the pump,
# - the vibration value
# - and a label indicating an anmonaly.

# %%
df.tail(5)
# Out:
#                              id      value  label
# time
# 2020-04-23 13:19:38.000  pump-2  43.276667      1
# 2020-04-23 13:19:39.617  pump-1  15.709151      0
# 2020-04-23 13:19:42.999  pump-2  16.214949      0
# 2020-04-23 13:19:44.617  pump-1  15.393048      0
# 2020-04-23 13:19:47.999  pump-2  14.855999      0

# %% [markdown]
# ### Visualize data
# - The uppper graph show a subset of the vibration data.
# - The lower graph illustrates the anomalies (1 = anomaly, 0 = normal)

# %%
df21 = df.head(100)
df21.plot(figsize=(20,10), fontsize=12,subplots=True, style=["-","o"], title = "Pump 2 - 100 Values")
plt.show()

# %% [markdown]
# ## Data Wrangling
# Goal: Convert time series data into small episodes that can be uses for supervised learning.

# %%
#
# Few helper functions
#

# Get list with column names: F1, F2, Fn, L
def get_columns(n):
    f = []
    for x in range(1,n+1):
        f.append("F"+str(x))
    f.append("L")
    return f

# Create empty data frame
def create_empty_df(n):
    d= ([0.]*n)
    d.append(0)
    dfx = pd.DataFrame([d], columns=get_columns(n))
    dfx.drop(dfx.index[0], inplace=True)
    return dfx

# Create data frame with one row
def create_df(vals: list, label: int = 0):
    if not isinstance(vals, list):
        raise TypeError
    #vals.append(label)    
    dfx = pd.DataFrame([vals+[label]], columns=get_columns(len(vals)))
    return dfx

# %% [markdown]
# Create a new dataframe: Rows represent the last x (length) value and the label.
#
#
# ```
# | tz | value | label |
# |----|-------|-------|
# | .. |   ... |   .   |
# | 04 |   6.2 |   0   |
# | 05 |   7.2 |   0   |
# | 06 |   5.1 |   0   |
# | 07 |   6.4 |   0   |
# | 08 |   2.2 |   0   |
# | 09 |  12.4 |   0   |
# | 10 |   8.4 |   1   |
# | .. |   ... |   .   |
# ```
#
# Convert to episodes with lenght = 5
#
# ```
#
# | F1 | F2 | F3 | F4 | F5 |  L  |
# |----|----|----|----|----|---- |
# | 6.2| 7.2| 5.1| 6.4| 2.2|  0  |
# | 7.2| 5.1| 6.4| 2.2|12.4|  1  |
# | 5.1| 6.4| 2.2|12.4| 8.4|  0  |
#
#
# ```

# %%
length = 5 # Episode length

df_epis = create_empty_df(length)

for id in df.id.unique():
    # print("Convert data for: ", id)
    df2 = df.loc[df['id'] == id]
    # print ("\nRecords in df2 look like:\n")
    # print (df2.tail(5))
    epi = []
    for index, row in df2.iterrows():
        # print ("\nValue in index:", index)
        # print ("\nValue in row:", row)
        # print('%6.2f, %d' % (row['value'], row['label']))
        epi.append(row['value'])
        if len(epi) == length :
            df_row = create_df(epi,row['label'] )
            df_epis = df_epis.append(df_row, ignore_index=True)
            del(epi[0])
# Out:
# Convert data for:  pump-1
#
# Records in df2 look like:
#
#                              id      value  label
# time
# 2020-04-23 13:19:24.618  pump-1  17.661311      0
# 2020-04-23 13:19:29.617  pump-1  16.693243      0
# 2020-04-23 13:19:34.617  pump-1  16.053479      0
# 2020-04-23 13:19:39.617  pump-1  15.709151      0
# 2020-04-23 13:19:44.617  pump-1  15.393048      0
#
# Value in index: 2020-04-23 11:13:54.617000
#
# Value in row: id          pump-1
# value    18.340181
# label            0
# Name: 2020-04-23 11:13:54.617000, dtype: object
#  18.34, 0
#
# Value in index: 2020-04-23 11:13:59.618000
#
# Value in row: id          pump-1
# value    17.647661
# label            0
# Name: 2020-04-23 11:13:59.618000, dtype: object
#  17.65, 0
#
# Value in index: 2020-04-23 11:14:04.617000
#
# Value in row: id          pump-1
# value    16.874933
# label            0
# Name: 2020-04-23 11:14:04.617000, dtype: object
#  16.87, 0
#
# Value in index: 2020-04-23 11:14:09.617000
#
# Value in row: id          pump-1
# value    16.180807
# label            0
# Name: 2020-04-23 11:14:09.617000, dtype: object
#  16.18, 0
#
# Value in index: 2020-04-23 11:14:14.618000
#
# Value in row: id          pump-1
# value    15.407113
# label            0
# Name: 2020-04-23 11:14:14.618000, dtype: object
#  15.41, 0
#
# Value in index: 2020-04-23 11:14:19.617000
#
# Value in row: id          pump-1
# value    15.324012
# label            0
# Name: 2020-04-23 11:14:19.617000, dtype: object
#  15.32, 0
#
# Value in index: 2020-04-23 11:14:24.617000
#
# Value in row: id          pump-1
# value    13.470387
# label            0
# Name: 2020-04-23 11:14:24.617000, dtype: object
#  13.47, 0
#
# Value in index: 2020-04-23 11:14:29.617000
#
# Value in row: id          pump-1
# value    11.702384
# label            0
# Name: 2020-04-23 11:14:29.617000, dtype: object
#  11.70, 0
#
# Value in index: 2020-04-23 11:14:34.617000
#
# Value in row: id          pump-1
# value    11.176102
# label            0
# Name: 2020-04-23 11:14:34.617000, dtype: object
#  11.18, 0
#
# Value in index: 2020-04-23 11:14:39.617000
#
# Value in row: id          pump-1
# value    10.678349
# label            0
# Name: 2020-04-23 11:14:39.617000, dtype: object
#  10.68, 0
#
# Value in index: 2020-04-23 11:14:44.617000
#
# Value in row: id         pump-1
# value    9.831242
# label           0
# Name: 2020-04-23 11:14:44.617000, dtype: object
#   9.83, 0
#
# Value in index: 2020-04-23 11:14:49.619000
#
# Value in row: id          pump-1
# value    11.555063
# label            0
# Name: 2020-04-23 11:14:49.619000, dtype: object
#  11.56, 0
#
# Value in index: 2020-04-23 11:14:54.617000
#
# Value in row: id          pump-1
# value    13.197594
# label            0
# Name: 2020-04-23 11:14:54.617000, dtype: object
#  13.20, 0
#
# Value in index: 2020-04-23 11:14:59.617000
#
# Value in row: id          pump-1
# value    14.337077
# label            0
# Name: 2020-04-23 11:14:59.617000, dtype: object
#  14.34, 0
#
# Value in index: 2020-04-23 11:15:04.617000
#
# Value in row: id         pump-1
# value    15.02092
# label           0
# Name: 2020-04-23 11:15:04.617000, dtype: object
#  15.02, 0
#
# Value in index: 2020-04-23 11:15:09.617000
#
# Value in row: id         pump-1
# value    15.80265
# label           0
# Name: 2020-04-23 11:15:09.617000, dtype: object
#  15.80, 0
#
# Value in index: 2020-04-23 11:15:14.617000
#
# Value in row: id          pump-1
# value    17.343995
# label            0
# Name: 2020-04-23 11:15:14.617000, dtype: object
#  17.34, 0
#
# Value in index: 2020-04-23 11:15:19.617000
#
# Value in row: id         pump-1
# value    16.41322
# label           0
# Name: 2020-04-23 11:15:19.617000, dtype: object
#  16.41, 0
#
# Value in index: 2020-04-23 11:15:24.617000
#
# Value in row: id          pump-1
# value    15.711286
# label            0
# Name: 2020-04-23 11:15:24.617000, dtype: object
#  15.71, 0
#
# Value in index: 2020-04-23 11:15:29.617000
#
# Value in row: id          pump-1
# value    14.035776
# label            0
# Name: 2020-04-23 11:15:29.617000, dtype: object
#  14.04, 0
#
# Value in index: 2020-04-23 11:15:34.617000
#
# Value in row: id          pump-1
# value    12.314211
# label            0
# Name: 2020-04-23 11:15:34.617000, dtype: object
#  12.31, 0
#
# Value in index: 2020-04-23 11:15:39.617000
#
# Value in row: id          pump-1
# value    11.173016
# label            0
# Name: 2020-04-23 11:15:39.617000, dtype: object
#  11.17, 0
#
# Value in index: 2020-04-23 11:15:44.617000
#
# Value in row: id          pump-1
# value    10.768019
# label            0
# Name: 2020-04-23 11:15:44.617000, dtype: object
#  10.77, 0
#
# Value in index: 2020-04-23 11:15:49.617000
#
# Value in row: id         pump-1
# value    9.691997
# label           0
# Name: 2020-04-23 11:15:49.617000, dtype: object
#   9.69, 0
#
# Value in index: 2020-04-23 11:15:54.617000
#
# Value in row: id          pump-1
# value    10.818096
# label            0
# Name: 2020-04-23 11:15:54.617000, dtype: object
#  10.82, 0
#
# Value in index: 2020-04-23 11:15:59.617000
#
# Value in row: id          pump-1
# value    12.299118
# label            0
# Name: 2020-04-23 11:15:59.617000, dtype: object
#  12.30, 0
#
# Value in index: 2020-04-23 11:16:04.617000
#
# Value in row: id          pump-1
# value    12.869831
# label            0
# Name: 2020-04-23 11:16:04.617000, dtype: object
#  12.87, 0
#
# Value in index: 2020-04-23 11:16:09.617000
#
# Value in row: id          pump-1
# value    36.690836
# label            1
# Name: 2020-04-23 11:16:09.617000, dtype: object
#  36.69, 1
#
# Value in index: 2020-04-23 11:16:14.617000
#
# Value in row: id          pump-1
# value    16.278101
# label            0
# Name: 2020-04-23 11:16:14.617000, dtype: object
#  16.28, 0
#
# Value in index: 2020-04-23 11:16:19.617000
#
# Value in row: id         pump-1
# value    18.21004
# label           0
# Name: 2020-04-23 11:16:19.617000, dtype: object
#  18.21, 0
#
# Value in index: 2020-04-23 11:16:24.617000
#
# Value in row: id          pump-1
# value    18.037584
# label            0
# Name: 2020-04-23 11:16:24.617000, dtype: object
#  18.04, 0
#
# Value in index: 2020-04-23 11:16:29.617000
#
# Value in row: id          pump-1
# value    16.514194
# label            0
# Name: 2020-04-23 11:16:29.617000, dtype: object
#  16.51, 0
#
# Value in index: 2020-04-23 11:16:34.617000
#
# Value in row: id          pump-1
# value    16.403727
# label            0
# Name: 2020-04-23 11:16:34.617000, dtype: object
#  16.40, 0
#
# Value in index: 2020-04-23 11:16:39.617000
#
# Value in row: id         pump-1
# value    14.55941
# label           0
# Name: 2020-04-23 11:16:39.617000, dtype: object
#  14.56, 0
#
# Value in index: 2020-04-23 11:16:44.617000
#
# Value in row: id          pump-1
# value    12.633224
# label            0
# Name: 2020-04-23 11:16:44.617000, dtype: object
#  12.63, 0
#
# Value in index: 2020-04-23 11:16:49.617000
#
# Value in row: id          pump-1
# value    10.717098
# label            0
# Name: 2020-04-23 11:16:49.617000, dtype: object
#  10.72, 0
#
# Value in index: 2020-04-23 11:16:54.617000
#
# Value in row: id          pump-1
# value    10.013827
# label            0
# Name: 2020-04-23 11:16:54.617000, dtype: object
#  10.01, 0
#
# Value in index: 2020-04-23 11:16:59.617000
#
# Value in row: id         pump-1
# value    9.649708
# label           0
# Name: 2020-04-23 11:16:59.617000, dtype: object
#   9.65, 0
#
# Value in index: 2020-04-23 11:17:04.617000
#
# Value in row: id          pump-1
# value    11.107449
# label            0
# Name: 2020-04-23 11:17:04.617000, dtype: object
#  11.11, 0
#
# Value in index: 2020-04-23 11:17:09.617000
#
# Value in row: id          pump-1
# value    11.535809
# label            0
# Name: 2020-04-23 11:17:09.617000, dtype: object
#  11.54, 0
#
# Value in index: 2020-04-23 11:17:14.617000
#
# Value in row: id          pump-1
# value    13.275943
# label            0
# Name: 2020-04-23 11:17:14.617000, dtype: object
#  13.28, 0
#
# Value in index: 2020-04-23 11:17:19.617000
#
# Value in row: id          pump-1
# value    14.296203
# label            0
# Name: 2020-04-23 11:17:19.617000, dtype: object
#  14.30, 0
#
# Value in index: 2020-04-23 11:17:24.618000
#
# Value in row: id          pump-1
# value    14.888701
# label            0
# Name: 2020-04-23 11:17:24.618000, dtype: object
#  14.89, 0
#
# Value in index: 2020-04-23 11:17:29.617000
#
# Value in row: id          pump-1
# value    15.476554
# label            0
# Name: 2020-04-23 11:17:29.617000, dtype: object
#  15.48, 0
#
# Value in index: 2020-04-23 11:17:34.617000
#
# Value in row: id          pump-1
# value    17.433367
# label            0
# Name: 2020-04-23 11:17:34.617000, dtype: object
#  17.43, 0
#
# Value in index: 2020-04-23 11:17:39.617000
#
# Value in row: id          pump-1
# value    17.210221
# label            0
# Name: 2020-04-23 11:17:39.617000, dtype: object
#  17.21, 0
#
# Value in index: 2020-04-23 11:17:44.617000
#
# Value in row: id          pump-1
# value    16.299877
# label            0
# Name: 2020-04-23 11:17:44.617000, dtype: object
#  16.30, 0
#
# Value in index: 2020-04-23 11:17:49.617000
#
# Value in row: id          pump-1
# value    15.720219
# label            0
# Name: 2020-04-23 11:17:49.617000, dtype: object
#  15.72, 0
#
# Value in index: 2020-04-23 11:17:54.617000
#
# Value in row: id          pump-1
# value    14.326126
# label            0
# Name: 2020-04-23 11:17:54.617000, dtype: object
#  14.33, 0
#
# Value in index: 2020-04-23 11:17:59.617000
#
# Value in row: id          pump-1
# value    13.264555
# label            0
# Name: 2020-04-23 11:17:59.617000, dtype: object
#  13.26, 0
#
# Value in index: 2020-04-23 11:18:04.617000
#
# Value in row: id          pump-1
# value    13.038821
# label            0
# Name: 2020-04-23 11:18:04.617000, dtype: object
#  13.04, 0
#
# Value in index: 2020-04-23 11:18:09.617000
#
# Value in row: id          pump-1
# value    11.144888
# label            0
# Name: 2020-04-23 11:18:09.617000, dtype: object
#  11.14, 0
#
# Value in index: 2020-04-23 11:18:14.617000
#
# Value in row: id        pump-1
# value    9.69547
# label          0
# Name: 2020-04-23 11:18:14.617000, dtype: object
#   9.70, 0
#
# Value in index: 2020-04-23 11:18:19.617000
#
# Value in row: id         pump-1
# value    9.818152
# label           0
# Name: 2020-04-23 11:18:19.617000, dtype: object
#   9.82, 0
#
# Value in index: 2020-04-23 11:18:24.617000
#
# Value in row: id          pump-1
# value    10.595578
# label            0
# Name: 2020-04-23 11:18:24.617000, dtype: object
#  10.60, 0
#
# Value in index: 2020-04-23 11:18:29.617000
#
# Value in row: id          pump-1
# value    12.267121
# label            0
# Name: 2020-04-23 11:18:29.617000, dtype: object
#  12.27, 0
#
# Value in index: 2020-04-23 11:18:34.617000
#
# Value in row: id         pump-1
# value    14.26055
# label           0
# Name: 2020-04-23 11:18:34.617000, dtype: object
#  14.26, 0
#
# Value in index: 2020-04-23 11:18:39.617000
#
# Value in row: id          pump-1
# value    15.455261
# label            0
# Name: 2020-04-23 11:18:39.617000, dtype: object
#  15.46, 0
#
# Value in index: 2020-04-23 11:18:44.617000
#
# Value in row: id          pump-1
# value    16.652005
# label            0
# Name: 2020-04-23 11:18:44.617000, dtype: object
#  16.65, 0
#
# Value in index: 2020-04-23 11:18:49.617000
#
# Value in row: id          pump-1
# value    17.741029
# label            0
# Name: 2020-04-23 11:18:49.617000, dtype: object
#  17.74, 0
#
# Value in index: 2020-04-23 11:18:54.617000
#
# Value in row: id         pump-1
# value    17.49253
# label           0
# Name: 2020-04-23 11:18:54.617000, dtype: object
#  17.49, 0
#
# Value in index: 2020-04-23 11:18:59.617000
#
# Value in row: id          pump-1
# value    16.290143
# label            0
# Name: 2020-04-23 11:18:59.617000, dtype: object
#  16.29, 0
#
# Value in index: 2020-04-23 11:19:04.619000
#
# Value in row: id          pump-1
# value    15.945017
# label            0
# Name: 2020-04-23 11:19:04.619000, dtype: object
#  15.95, 0
#
# Value in index: 2020-04-23 11:19:09.617000
#
# Value in row: id          pump-1
# value    15.178494
# label            0
# Name: 2020-04-23 11:19:09.617000, dtype: object
#  15.18, 0
#
# Value in index: 2020-04-23 11:19:14.617000
#
# Value in row: id          pump-1
# value    14.309016
# label            0
# Name: 2020-04-23 11:19:14.617000, dtype: object
#  14.31, 0
#
# Value in index: 2020-04-23 11:19:19.617000
#
# Value in row: id          pump-1
# value    13.178729
# label            0
# Name: 2020-04-23 11:19:19.617000, dtype: object
#  13.18, 0
#
# Value in index: 2020-04-23 11:19:24.618000
#
# Value in row: id          pump-1
# value    11.515797
# label            0
# Name: 2020-04-23 11:19:24.618000, dtype: object
#  11.52, 0
#
# Value in index: 2020-04-23 11:19:29.617000
#
# Value in row: id          pump-1
# value    10.215053
# label            0
# Name: 2020-04-23 11:19:29.617000, dtype: object
#  10.22, 0
#
# Value in index: 2020-04-23 11:19:34.617000
#
# Value in row: id        pump-1
# value    8.37347
# label          0
# Name: 2020-04-23 11:19:34.617000, dtype: object
#   8.37, 0
#
# Value in index: 2020-04-23 11:19:39.617000
#
# Value in row: id         pump-1
# value    9.515462
# label           0
# Name: 2020-04-23 11:19:39.617000, dtype: object
#   9.52, 0
#
# Value in index: 2020-04-23 11:19:44.617000
#
# Value in row: id         pump-1
# value    9.625459
# label           0
# Name: 2020-04-23 11:19:44.617000, dtype: object
#   9.63, 0
#
# Value in index: 2020-04-23 11:19:49.617000
#
# Value in row: id         pump-1
# value    10.10662
# label           0
# Name: 2020-04-23 11:19:49.617000, dtype: object
#  10.11, 0
#
# Value in index: 2020-04-23 11:19:54.617000
#
# Value in row: id          pump-1
# value    10.926193
# label            0
# Name: 2020-04-23 11:19:54.617000, dtype: object
#  10.93, 0
#
# Value in index: 2020-04-23 11:19:59.617000
#
# Value in row: id          pump-1
# value    12.450826
# label            0
# Name: 2020-04-23 11:19:59.617000, dtype: object
#  12.45, 0
#
# Value in index: 2020-04-23 11:20:04.618000
#
# Value in row: id          pump-1
# value    13.533894
# label            0
# Name: 2020-04-23 11:20:04.618000, dtype: object
#  13.53, 0
#
# Value in index: 2020-04-23 11:20:09.617000
#
# Value in row: id          pump-1
# value    13.804645
# label            0
# Name: 2020-04-23 11:20:09.617000, dtype: object
#  13.80, 0
#
# Value in index: 2020-04-23 11:20:14.617000
#
# Value in row: id          pump-1
# value    15.744194
# label            0
# Name: 2020-04-23 11:20:14.617000, dtype: object
#  15.74, 0
#
# Value in index: 2020-04-23 11:20:19.618000
#
# Value in row: id          pump-1
# value    17.127318
# label            0
# Name: 2020-04-23 11:20:19.618000, dtype: object
#  17.13, 0
#
# Value in index: 2020-04-23 11:20:24.617000
#
# Value in row: id          pump-1
# value    15.553445
# label            0
# Name: 2020-04-23 11:20:24.617000, dtype: object
#  15.55, 0
#
# Value in index: 2020-04-23 11:20:29.617000
#
# Value in row: id          pump-1
# value    14.132293
# label            0
# Name: 2020-04-23 11:20:29.617000, dtype: object
#  14.13, 0
#
# Value in index: 2020-04-23 11:20:34.617000
#
# Value in row: id         pump-1
# value    13.36437
# label           0
# Name: 2020-04-23 11:20:34.617000, dtype: object
#  13.36, 0
#
# Value in index: 2020-04-23 11:20:39.617000
#
# Value in row: id          pump-1
# value    12.359368
# label            0
# Name: 2020-04-23 11:20:39.617000, dtype: object
#  12.36, 0
#
# Value in index: 2020-04-23 11:20:44.618000
#
# Value in row: id          pump-1
# value    11.514429
# label            0
# Name: 2020-04-23 11:20:44.618000, dtype: object
#  11.51, 0
#
# Value in index: 2020-04-23 11:20:49.617000
#
# Value in row: id          pump-1
# value    11.089619
# label            0
# Name: 2020-04-23 11:20:49.617000, dtype: object
#  11.09, 0
#
# Value in index: 2020-04-23 11:20:54.617000
#
# Value in row: id         pump-1
# value    9.679927
# label           0
# Name: 2020-04-23 11:20:54.617000, dtype: object
#   9.68, 0
#
# Value in index: 2020-04-23 11:20:59.617000
#
# Value in row: id          pump-1
# value    11.029811
# label            0
# Name: 2020-04-23 11:20:59.617000, dtype: object
#  11.03, 0
#
# Value in index: 2020-04-23 11:21:04.617000
#
# Value in row: id          pump-1
# value    12.662729
# label            0
# Name: 2020-04-23 11:21:04.617000, dtype: object
#  12.66, 0
#
# Value in index: 2020-04-23 11:21:09.617000
#
# Value in row: id          pump-1
# value    13.590655
# label            0
# Name: 2020-04-23 11:21:09.617000, dtype: object
#  13.59, 0
#
# Value in index: 2020-04-23 11:21:14.617000
#
# Value in row: id          pump-1
# value    14.780586
# label            0
# Name: 2020-04-23 11:21:14.617000, dtype: object
#  14.78, 0
#
# Value in index: 2020-04-23 11:21:19.617000
#
# Value in row: id          pump-1
# value    16.206462
# label            0
# Name: 2020-04-23 11:21:19.617000, dtype: object
#  16.21, 0
#
# Value in index: 2020-04-23 11:21:24.618000
#
# Value in row: id          pump-1
# value    16.632557
# label            0
# Name: 2020-04-23 11:21:24.618000, dtype: object
#  16.63, 0
#
# Value in index: 2020-04-23 11:21:29.618000
#
# Value in row: id          pump-1
# value    17.158073
# label            0
# Name: 2020-04-23 11:21:29.618000, dtype: object
#  17.16, 0
#
# Value in index: 2020-04-23 11:21:34.617000
#
# Value in row: id          pump-1
# value    16.442799
# label            0
# Name: 2020-04-23 11:21:34.617000, dtype: object
#  16.44, 0
#
# Value in index: 2020-04-23 11:21:39.618000
#
# Value in row: id          pump-1
# value    14.985618
# label            0
# Name: 2020-04-23 11:21:39.618000, dtype: object
#  14.99, 0
#
# Value in index: 2020-04-23 11:21:44.617000
#
# Value in row: id          pump-1
# value    13.110522
# label            0
# Name: 2020-04-23 11:21:44.617000, dtype: object
#  13.11, 0
#
# Value in index: 2020-04-23 11:21:49.617000
#
# Value in row: id          pump-1
# value    12.413659
# label            0
# Name: 2020-04-23 11:21:49.617000, dtype: object
#  12.41, 0
#
# Value in index: 2020-04-23 11:21:54.618000
#
# Value in row: id          pump-1
# value    11.047131
# label            0
# Name: 2020-04-23 11:21:54.618000, dtype: object
#  11.05, 0
#
# Value in index: 2020-04-23 11:21:59.617000
#
# Value in row: id         pump-1
# value    9.706778
# label           0
# Name: 2020-04-23 11:21:59.617000, dtype: object
#   9.71, 0
#
# Value in index: 2020-04-23 11:22:04.617000
#
# Value in row: id          pump-1
# value    10.731597
# label            0
# Name: 2020-04-23 11:22:04.617000, dtype: object
#  10.73, 0
#
# Value in index: 2020-04-23 11:22:09.617000
#
# Value in row: id          pump-1
# value    11.817568
# label            0
# Name: 2020-04-23 11:22:09.617000, dtype: object
#  11.82, 0
#
# Value in index: 2020-04-23 11:22:14.619000
#
# Value in row: id          pump-1
# value    11.863296
# label            0
# Name: 2020-04-23 11:22:14.619000, dtype: object
#  11.86, 0
#
# Value in index: 2020-04-23 11:22:19.617000
#
# Value in row: id          pump-1
# value    12.196805
# label            0
# Name: 2020-04-23 11:22:19.617000, dtype: object
#  12.20, 0
#
# Value in index: 2020-04-23 11:22:24.617000
#
# Value in row: id         pump-1
# value    13.85054
# label           0
# Name: 2020-04-23 11:22:24.617000, dtype: object
#  13.85, 0
#
# Value in index: 2020-04-23 11:22:29.617000
#
# Value in row: id          pump-1
# value    15.349217
# label            0
# Name: 2020-04-23 11:22:29.617000, dtype: object
#  15.35, 0
#
# Value in index: 2020-04-23 11:22:34.617000
#
# Value in row: id          pump-1
# value    15.956714
# label            0
# Name: 2020-04-23 11:22:34.617000, dtype: object
#  15.96, 0
#
# Value in index: 2020-04-23 11:22:39.617000
#
# Value in row: id          pump-1
# value    16.768924
# label            0
# Name: 2020-04-23 11:22:39.617000, dtype: object
#  16.77, 0
#
# Value in index: 2020-04-23 11:22:44.617000
#
# Value in row: id          pump-1
# value    16.985902
# label            0
# Name: 2020-04-23 11:22:44.617000, dtype: object
#  16.99, 0
#
# Value in index: 2020-04-23 11:22:49.617000
#
# Value in row: id          pump-1
# value    17.006497
# label            0
# Name: 2020-04-23 11:22:49.617000, dtype: object
#  17.01, 0
#
# Value in index: 2020-04-23 11:22:54.617000
#
# Value in row: id          pump-1
# value    15.508431
# label            0
# Name: 2020-04-23 11:22:54.617000, dtype: object
#  15.51, 0
#
# Value in index: 2020-04-23 11:22:59.617000
#
# Value in row: id          pump-1
# value    14.691133
# label            0
# Name: 2020-04-23 11:22:59.617000, dtype: object
#  14.69, 0
#
# Value in index: 2020-04-23 11:23:04.617000
#
# Value in row: id          pump-1
# value    13.622232
# label            0
# Name: 2020-04-23 11:23:04.617000, dtype: object
#  13.62, 0
#
# Value in index: 2020-04-23 11:23:09.617000
#
# Value in row: id          pump-1
# value    12.700603
# label            0
# Name: 2020-04-23 11:23:09.617000, dtype: object
#  12.70, 0
#
# Value in index: 2020-04-23 11:23:14.617000
#
# Value in row: id          pump-1
# value    11.176675
# label            0
# Name: 2020-04-23 11:23:14.617000, dtype: object
#  11.18, 0
#
# Value in index: 2020-04-23 11:23:19.617000
#
# Value in row: id          pump-1
# value    10.353632
# label            0
# Name: 2020-04-23 11:23:19.617000, dtype: object
#  10.35, 0
#
# Value in index: 2020-04-23 11:23:24.617000
#
# Value in row: id         pump-1
# value    8.590011
# label           0
# Name: 2020-04-23 11:23:24.617000, dtype: object
#   8.59, 0
#
# Value in index: 2020-04-23 11:23:29.617000
#
# Value in row: id          pump-1
# value    10.517173
# label            0
# Name: 2020-04-23 11:23:29.617000, dtype: object
#  10.52, 0
#
# Value in index: 2020-04-23 11:23:34.617000
#
# Value in row: id          pump-1
# value    11.514577
# label            0
# Name: 2020-04-23 11:23:34.617000, dtype: object
#  11.51, 0
#
# Value in index: 2020-04-23 11:23:39.617000
#
# Value in row: id          pump-1
# value    12.767237
# label            0
# Name: 2020-04-23 11:23:39.617000, dtype: object
#  12.77, 0
#
# Value in index: 2020-04-23 11:23:44.618000
#
# Value in row: id          pump-1
# value    13.194699
# label            0
# Name: 2020-04-23 11:23:44.618000, dtype: object
#  13.19, 0
#
# Value in index: 2020-04-23 11:23:49.617000
#
# Value in row: id          pump-1
# value    14.806792
# label            0
# Name: 2020-04-23 11:23:49.617000, dtype: object
#  14.81, 0
#
# Value in index: 2020-04-23 11:23:54.617000
#
# Value in row: id          pump-1
# value    16.603018
# label            0
# Name: 2020-04-23 11:23:54.617000, dtype: object
#  16.60, 0
#
# Value in index: 2020-04-23 11:23:59.617000
#
# Value in row: id          pump-1
# value    16.883135
# label            0
# Name: 2020-04-23 11:23:59.617000, dtype: object
#  16.88, 0
#
# Value in index: 2020-04-23 11:24:04.617000
#
# Value in row: id          pump-1
# value    18.836762
# label            0
# Name: 2020-04-23 11:24:04.617000, dtype: object
#  18.84, 0
#
# Value in index: 2020-04-23 11:24:09.617000
#
# Value in row: id          pump-1
# value    18.461253
# label            0
# Name: 2020-04-23 11:24:09.617000, dtype: object
#  18.46, 0
#
# Value in index: 2020-04-23 11:24:14.617000
#
# Value in row: id         pump-1
# value    17.23395
# label           0
# Name: 2020-04-23 11:24:14.617000, dtype: object
#  17.23, 0
#
# Value in index: 2020-04-23 11:24:19.617000
#
# Value in row: id          pump-1
# value    16.246621
# label            0
# Name: 2020-04-23 11:24:19.617000, dtype: object
#  16.25, 0
#
# Value in index: 2020-04-23 11:24:24.617000
#
# Value in row: id          pump-1
# value    14.640216
# label            0
# Name: 2020-04-23 11:24:24.617000, dtype: object
#  14.64, 0
#
# Value in index: 2020-04-23 11:24:29.617000
#
# Value in row: id          pump-1
# value    13.688733
# label            0
# Name: 2020-04-23 11:24:29.617000, dtype: object
#  13.69, 0
#
# Value in index: 2020-04-23 11:24:34.617000
#
# Value in row: id          pump-1
# value    12.407744
# label            0
# Name: 2020-04-23 11:24:34.617000, dtype: object
#  12.41, 0
#
# Value in index: 2020-04-23 11:24:39.617000
#
# Value in row: id          pump-1
# value    11.063815
# label            0
# Name: 2020-04-23 11:24:39.617000, dtype: object
#  11.06, 0
#
# Value in index: 2020-04-23 11:24:44.617000
#
# Value in row: id         pump-1
# value    9.353136
# label           0
# Name: 2020-04-23 11:24:44.617000, dtype: object
#   9.35, 0
#
# Value in index: 2020-04-23 11:24:49.617000
#
# Value in row: id          pump-1
# value    10.849422
# label            0
# Name: 2020-04-23 11:24:49.617000, dtype: object
#  10.85, 0
#
# Value in index: 2020-04-23 11:24:54.618000
#
# Value in row: id          pump-1
# value    11.329878
# label            0
# Name: 2020-04-23 11:24:54.618000, dtype: object
#  11.33, 0
#
# Value in index: 2020-04-23 11:24:59.617000
#
# Value in row: id          pump-1
# value    11.762319
# label            0
# Name: 2020-04-23 11:24:59.617000, dtype: object
#  11.76, 0
#
# Value in index: 2020-04-23 11:25:04.617000
#
# Value in row: id          pump-1
# value    12.489184
# label            0
# Name: 2020-04-23 11:25:04.617000, dtype: object
#  12.49, 0
#
# Value in index: 2020-04-23 11:25:09.618000
#
# Value in row: id          pump-1
# value    13.789552
# label            0
# Name: 2020-04-23 11:25:09.618000, dtype: object
#  13.79, 0
#
# Value in index: 2020-04-23 11:25:14.617000
#
# Value in row: id          pump-1
# value    14.337618
# label            0
# Name: 2020-04-23 11:25:14.617000, dtype: object
#  14.34, 0
#
# Value in index: 2020-04-23 11:25:19.617000
#
# Value in row: id          pump-1
# value    15.259762
# label            0
# Name: 2020-04-23 11:25:19.617000, dtype: object
#  15.26, 0
#
# Value in index: 2020-04-23 11:25:24.617000
#
# Value in row: id          pump-1
# value    16.084891
# label            0
# Name: 2020-04-23 11:25:24.617000, dtype: object
#  16.08, 0
#
# Value in index: 2020-04-23 11:25:29.617000
#
# Value in row: id          pump-1
# value    16.915332
# label            0
# Name: 2020-04-23 11:25:29.617000, dtype: object
#  16.92, 0
#
# Value in index: 2020-04-23 11:25:34.618000
#
# Value in row: id          pump-1
# value    17.608415
# label            0
# Name: 2020-04-23 11:25:34.618000, dtype: object
#  17.61, 0
#
# Value in index: 2020-04-23 11:25:39.617000
#
# Value in row: id          pump-1
# value    16.244401
# label            0
# Name: 2020-04-23 11:25:39.617000, dtype: object
#  16.24, 0
#
# Value in index: 2020-04-23 11:25:44.617000
#
# Value in row: id          pump-1
# value    14.912587
# label            0
# Name: 2020-04-23 11:25:44.617000, dtype: object
#  14.91, 0
#
# Value in index: 2020-04-23 11:25:49.617000
#
# Value in row: id          pump-1
# value    13.171428
# label            0
# Name: 2020-04-23 11:25:49.617000, dtype: object
#  13.17, 0
#
# Value in index: 2020-04-23 11:25:54.617000
#
# Value in row: id          pump-1
# value    11.609046
# label            0
# Name: 2020-04-23 11:25:54.617000, dtype: object
#  11.61, 0
#
# Value in index: 2020-04-23 11:25:59.617000
#
# Value in row: id          pump-1
# value    11.378149
# label            0
# Name: 2020-04-23 11:25:59.617000, dtype: object
#  11.38, 0
#
# Value in index: 2020-04-23 11:26:04.624000
#
# Value in row: id         pump-1
# value    9.799493
# label           0
# Name: 2020-04-23 11:26:04.624000, dtype: object
#   9.80, 0
#
# Value in index: 2020-04-23 11:26:09.617000
#
# Value in row: id          pump-1
# value    10.877805
# label            0
# Name: 2020-04-23 11:26:09.617000, dtype: object
#  10.88, 0
#
# Value in index: 2020-04-23 11:26:14.617000
#
# Value in row: id          pump-1
# value    12.156633
# label            0
# Name: 2020-04-23 11:26:14.617000, dtype: object
#  12.16, 0
#
# Value in index: 2020-04-23 11:26:19.617000
#
# Value in row: id          pump-1
# value    13.678226
# label            0
# Name: 2020-04-23 11:26:19.617000, dtype: object
#  13.68, 0
#
# Value in index: 2020-04-23 11:26:24.617000
#
# Value in row: id          pump-1
# value    15.565539
# label            0
# Name: 2020-04-23 11:26:24.617000, dtype: object
#  15.57, 0
#
# Value in index: 2020-04-23 11:26:29.617000
#
# Value in row: id          pump-1
# value    16.044709
# label            0
# Name: 2020-04-23 11:26:29.617000, dtype: object
#  16.04, 0
#
# Value in index: 2020-04-23 11:26:34.617000
#
# Value in row: id         pump-1
# value    17.84276
# label           0
# Name: 2020-04-23 11:26:34.617000, dtype: object
#  17.84, 0
#
# Value in index: 2020-04-23 11:26:39.617000
#
# Value in row: id          pump-1
# value    16.902131
# label            0
# Name: 2020-04-23 11:26:39.617000, dtype: object
#  16.90, 0
#
# Value in index: 2020-04-23 11:26:44.617000
#
# Value in row: id         pump-1
# value    15.33066
# label           0
# Name: 2020-04-23 11:26:44.617000, dtype: object
#  15.33, 0
#
# Value in index: 2020-04-23 11:26:49.617000
#
# Value in row: id         pump-1
# value    14.24081
# label           0
# Name: 2020-04-23 11:26:49.617000, dtype: object
#  14.24, 0
#
# Value in index: 2020-04-23 11:26:54.617000
#
# Value in row: id          pump-1
# value    14.037606
# label            0
# Name: 2020-04-23 11:26:54.617000, dtype: object
#  14.04, 0
#
# Value in index: 2020-04-23 11:26:59.617000
#
# Value in row: id          pump-1
# value    13.639235
# label            0
# Name: 2020-04-23 11:26:59.617000, dtype: object
#  13.64, 0
#
# Value in index: 2020-04-23 11:27:04.618000
#
# Value in row: id          pump-1
# value    12.935627
# label            0
# Name: 2020-04-23 11:27:04.618000, dtype: object
#  12.94, 0
#
# Value in index: 2020-04-23 11:27:09.617000
#
# Value in row: id         pump-1
# value    12.64604
# label           0
# Name: 2020-04-23 11:27:09.617000, dtype: object
#  12.65, 0
#
# Value in index: 2020-04-23 11:27:14.617000
#
# Value in row: id          pump-1
# value    11.101233
# label            0
# Name: 2020-04-23 11:27:14.617000, dtype: object
#  11.10, 0
#
# Value in index: 2020-04-23 11:27:19.617000
#
# Value in row: id          pump-1
# value    10.296374
# label            0
# Name: 2020-04-23 11:27:19.617000, dtype: object
#  10.30, 0
#
# Value in index: 2020-04-23 11:27:24.618000
#
# Value in row: id         pump-1
# value    8.519754
# label           0
# Name: 2020-04-23 11:27:24.618000, dtype: object
#   8.52, 0
#
# Value in index: 2020-04-23 11:27:29.618000
#
# Value in row: id         pump-1
# value    8.671313
# label           0
# Name: 2020-04-23 11:27:29.618000, dtype: object
#   8.67, 0
#
# Value in index: 2020-04-23 11:27:34.617000
#
# Value in row: id         pump-1
# value    9.129209
# label           0
# Name: 2020-04-23 11:27:34.617000, dtype: object
#   9.13, 0
#
# Value in index: 2020-04-23 11:27:39.617000
#
# Value in row: id          pump-1
# value    10.829487
# label            0
# Name: 2020-04-23 11:27:39.617000, dtype: object
#  10.83, 0
#
# Value in index: 2020-04-23 11:27:44.617000
#
# Value in row: id          pump-1
# value    11.950104
# label            0
# Name: 2020-04-23 11:27:44.617000, dtype: object
#  11.95, 0
#
# Value in index: 2020-04-23 11:27:49.618000
#
# Value in row: id          pump-1
# value    13.660659
# label            0
# Name: 2020-04-23 11:27:49.618000, dtype: object
#  13.66, 0
#
# Value in index: 2020-04-23 11:27:54.617000
#
# Value in row: id          pump-1
# value    13.986546
# label            0
# Name: 2020-04-23 11:27:54.617000, dtype: object
#  13.99, 0
#
# Value in index: 2020-04-23 11:27:59.618000
#
# Value in row: id         pump-1
# value    15.07795
# label           0
# Name: 2020-04-23 11:27:59.618000, dtype: object
#  15.08, 0
#
# Value in index: 2020-04-23 11:28:04.617000
#
# Value in row: id         pump-1
# value    16.28461
# label           0
# Name: 2020-04-23 11:28:04.617000, dtype: object
#  16.28, 0
#
# Value in index: 2020-04-23 11:28:09.618000
#
# Value in row: id         pump-1
# value    17.94755
# label           0
# Name: 2020-04-23 11:28:09.618000, dtype: object
#  17.95, 0
#
# Value in index: 2020-04-23 11:28:14.617000
#
# Value in row: id          pump-1
# value    17.576552
# label            0
# Name: 2020-04-23 11:28:14.617000, dtype: object
#  17.58, 0
#
# Value in index: 2020-04-23 11:28:19.617000
#
# Value in row: id          pump-1
# value    16.879004
# label            0
# Name: 2020-04-23 11:28:19.617000, dtype: object
#  16.88, 0
#
# Value in index: 2020-04-23 11:28:24.617000
#
# Value in row: id          pump-1
# value    14.923281
# label            0
# Name: 2020-04-23 11:28:24.617000, dtype: object
#  14.92, 0
#
# Value in index: 2020-04-23 11:28:29.617000
#
# Value in row: id          pump-1
# value    12.994668
# label            0
# Name: 2020-04-23 11:28:29.617000, dtype: object
#  12.99, 0
#
# Value in index: 2020-04-23 11:28:34.618000
#
# Value in row: id          pump-1
# value    12.685908
# label            0
# Name: 2020-04-23 11:28:34.618000, dtype: object
#  12.69, 0
#
# Value in index: 2020-04-23 11:28:39.617000
#
# Value in row: id          pump-1
# value    11.655421
# label            0
# Name: 2020-04-23 11:28:39.617000, dtype: object
#  11.66, 0
#
# Value in index: 2020-04-23 11:28:44.617000
#
# Value in row: id          pump-1
# value    10.050974
# label            0
# Name: 2020-04-23 11:28:44.617000, dtype: object
#  10.05, 0
#
# Value in index: 2020-04-23 11:28:49.617000
#
# Value in row: id         pump-1
# value    9.081054
# label           0
# Name: 2020-04-23 11:28:49.617000, dtype: object
#   9.08, 0
#
# Value in index: 2020-04-23 11:28:54.618000
#
# Value in row: id          pump-1
# value    10.184627
# label            0
# Name: 2020-04-23 11:28:54.618000, dtype: object
#  10.18, 0
#
# Value in index: 2020-04-23 11:28:59.617000
#
# Value in row: id          pump-1
# value    11.460246
# label            0
# Name: 2020-04-23 11:28:59.617000, dtype: object
#  11.46, 0
#
# Value in index: 2020-04-23 11:29:04.618000
#
# Value in row: id          pump-1
# value    12.754537
# label            0
# Name: 2020-04-23 11:29:04.618000, dtype: object
#  12.75, 0
#
# Value in index: 2020-04-23 11:29:09.617000
#
# Value in row: id          pump-1
# value    14.267229
# label            0
# Name: 2020-04-23 11:29:09.617000, dtype: object
#  14.27, 0
#
# Value in index: 2020-04-23 11:29:14.617000
#
# Value in row: id          pump-1
# value    15.819251
# label            0
# Name: 2020-04-23 11:29:14.617000, dtype: object
#  15.82, 0
#
# Value in index: 2020-04-23 11:29:19.617000
#
# Value in row: id          pump-1
# value    16.568827
# label            0
# Name: 2020-04-23 11:29:19.617000, dtype: object
#  16.57, 0
#
# Value in index: 2020-04-23 11:29:24.617000
#
# Value in row: id          pump-1
# value    17.951291
# label            0
# Name: 2020-04-23 11:29:24.617000, dtype: object
#  17.95, 0
#
# Value in index: 2020-04-23 11:29:29.617000
#
# Value in row: id          pump-1
# value    17.812767
# label            0
# Name: 2020-04-23 11:29:29.617000, dtype: object
#  17.81, 0
#
# Value in index: 2020-04-23 11:29:34.617000
#
# Value in row: id          pump-1
# value    16.846645
# label            0
# Name: 2020-04-23 11:29:34.617000, dtype: object
#  16.85, 0
#
# Value in index: 2020-04-23 11:29:39.617000
#
# Value in row: id          pump-1
# value    15.890581
# label            0
# Name: 2020-04-23 11:29:39.617000, dtype: object
#  15.89, 0
#
# Value in index: 2020-04-23 11:29:44.618000
#
# Value in row: id          pump-1
# value    14.731449
# label            0
# Name: 2020-04-23 11:29:44.618000, dtype: object
#  14.73, 0
#
# Value in index: 2020-04-23 11:29:49.618000
#
# Value in row: id          pump-1
# value    14.213845
# label            0
# Name: 2020-04-23 11:29:49.618000, dtype: object
#  14.21, 0
#
# Value in index: 2020-04-23 11:29:54.617000
#
# Value in row: id          pump-1
# value    14.105021
# label            0
# Name: 2020-04-23 11:29:54.617000, dtype: object
#  14.11, 0
#
# Value in index: 2020-04-23 11:29:59.617000
#
# Value in row: id          pump-1
# value    13.076799
# label            0
# Name: 2020-04-23 11:29:59.617000, dtype: object
#  13.08, 0
#
# Value in index: 2020-04-23 11:30:04.618000
#
# Value in row: id          pump-1
# value    12.989268
# label            0
# Name: 2020-04-23 11:30:04.618000, dtype: object
#  12.99, 0
#
# Value in index: 2020-04-23 11:30:09.617000
#
# Value in row: id          pump-1
# value    12.040688
# label            0
# Name: 2020-04-23 11:30:09.617000, dtype: object
#  12.04, 0
#
# Value in index: 2020-04-23 11:30:14.617000
#
# Value in row: id          pump-1
# value    10.709258
# label            0
# Name: 2020-04-23 11:30:14.617000, dtype: object
#  10.71, 0
#
# Value in index: 2020-04-23 11:30:19.617000
#
# Value in row: id         pump-1
# value    9.126626
# label           0
# Name: 2020-04-23 11:30:19.617000, dtype: object
#   9.13, 0
#
# Value in index: 2020-04-23 11:30:24.617000
#
# Value in row: id         pump-1
# value    9.800743
# label           0
# Name: 2020-04-23 11:30:24.617000, dtype: object
#   9.80, 0
#
# Value in index: 2020-04-23 11:30:29.617000
#
# Value in row: id          pump-1
# value    10.820974
# label            0
# Name: 2020-04-23 11:30:29.617000, dtype: object
#  10.82, 0
#
# Value in index: 2020-04-23 11:30:34.617000
#
# Value in row: id         pump-1
# value    12.65999
# label           0
# Name: 2020-04-23 11:30:34.617000, dtype: object
#  12.66, 0
#
# Value in index: 2020-04-23 11:30:39.617000
#
# Value in row: id          pump-1
# value    14.438215
# label            0
# Name: 2020-04-23 11:30:39.617000, dtype: object
#  14.44, 0
#
# Value in index: 2020-04-23 11:30:44.617000
#
# Value in row: id          pump-1
# value    15.272594
# label            0
# Name: 2020-04-23 11:30:44.617000, dtype: object
#  15.27, 0
#
# Value in index: 2020-04-23 11:30:49.617000
#
# Value in row: id          pump-1
# value    15.315351
# label            0
# Name: 2020-04-23 11:30:49.617000, dtype: object
#  15.32, 0
#
# Value in index: 2020-04-23 11:30:54.617000
#
# Value in row: id          pump-1
# value    16.190561
# label            0
# Name: 2020-04-23 11:30:54.617000, dtype: object
#  16.19, 0
#
# Value in index: 2020-04-23 11:30:59.617000
#
# Value in row: id         pump-1
# value    16.69593
# label           0
# Name: 2020-04-23 11:30:59.617000, dtype: object
#  16.70, 0
#
# Value in index: 2020-04-23 11:31:04.617000
#
# Value in row: id          pump-1
# value    17.287305
# label            0
# Name: 2020-04-23 11:31:04.617000, dtype: object
#  17.29, 0
#
# Value in index: 2020-04-23 11:31:09.618000
#
# Value in row: id          pump-1
# value    17.110084
# label            0
# Name: 2020-04-23 11:31:09.618000, dtype: object
#  17.11, 0
#
# Value in index: 2020-04-23 11:31:14.618000
#
# Value in row: id          pump-1
# value    15.985535
# label            0
# Name: 2020-04-23 11:31:14.618000, dtype: object
#  15.99, 0
#
# Value in index: 2020-04-23 11:31:19.617000
#
# Value in row: id          pump-1
# value    14.378272
# label            0
# Name: 2020-04-23 11:31:19.617000, dtype: object
#  14.38, 0
#
# Value in index: 2020-04-23 11:31:24.617000
#
# Value in row: id         pump-1
# value    13.48424
# label           0
# Name: 2020-04-23 11:31:24.617000, dtype: object
#  13.48, 0
#
# Value in index: 2020-04-23 11:31:29.617000
#
# Value in row: id          pump-1
# value    13.011328
# label            0
# Name: 2020-04-23 11:31:29.617000, dtype: object
#  13.01, 0
#
# Value in index: 2020-04-23 11:31:34.617000
#
# Value in row: id          pump-1
# value    12.515569
# label            0
# Name: 2020-04-23 11:31:34.617000, dtype: object
#  12.52, 0
#
# Value in index: 2020-04-23 11:31:39.618000
#
# Value in row: id          pump-1
# value    11.547531
# label            0
# Name: 2020-04-23 11:31:39.618000, dtype: object
#  11.55, 0
#
# Value in index: 2020-04-23 11:31:44.617000
#
# Value in row: id          pump-1
# value    10.487832
# label            0
# Name: 2020-04-23 11:31:44.617000, dtype: object
#  10.49, 0
#
# Value in index: 2020-04-23 11:31:49.617000
#
# Value in row: id         pump-1
# value    9.893975
# label           0
# Name: 2020-04-23 11:31:49.617000, dtype: object
#   9.89, 0
#
# Value in index: 2020-04-23 11:31:54.618000
#
# Value in row: id          pump-1
# value    10.775788
# label            0
# Name: 2020-04-23 11:31:54.618000, dtype: object
#  10.78, 0
#
# Value in index: 2020-04-23 11:31:59.618000
#
# Value in row: id          pump-1
# value    11.285672
# label            0
# Name: 2020-04-23 11:31:59.618000, dtype: object
#  11.29, 0
#
# Value in index: 2020-04-23 11:32:04.618000
#
# Value in row: id          pump-1
# value    12.504307
# label            0
# Name: 2020-04-23 11:32:04.618000, dtype: object
#  12.50, 0
#
# Value in index: 2020-04-23 11:32:09.617000
#
# Value in row: id          pump-1
# value    13.587007
# label            0
# Name: 2020-04-23 11:32:09.617000, dtype: object
#  13.59, 0
#
# Value in index: 2020-04-23 11:32:14.617000
#
# Value in row: id          pump-1
# value    13.739595
# label            0
# Name: 2020-04-23 11:32:14.617000, dtype: object
#  13.74, 0
#
# Value in index: 2020-04-23 11:32:19.617000
#
# Value in row: id          pump-1
# value    14.841744
# label            0
# Name: 2020-04-23 11:32:19.617000, dtype: object
#  14.84, 0
#
# Value in index: 2020-04-23 11:32:24.617000
#
# Value in row: id          pump-1
# value    15.275582
# label            0
# Name: 2020-04-23 11:32:24.617000, dtype: object
#  15.28, 0
#
# Value in index: 2020-04-23 11:32:29.617000
#
# Value in row: id          pump-1
# value    15.297343
# label            0
# Name: 2020-04-23 11:32:29.617000, dtype: object
#  15.30, 0
#
# Value in index: 2020-04-23 11:32:34.617000
#
# Value in row: id          pump-1
# value    16.152678
# label            0
# Name: 2020-04-23 11:32:34.617000, dtype: object
#  16.15, 0
#
# Value in index: 2020-04-23 11:32:39.617000
#
# Value in row: id          pump-1
# value    17.620249
# label            0
# Name: 2020-04-23 11:32:39.617000, dtype: object
#  17.62, 0
#
# Value in index: 2020-04-23 11:32:44.617000
#
# Value in row: id         pump-1
# value    15.88971
# label           0
# Name: 2020-04-23 11:32:44.617000, dtype: object
#  15.89, 0
#
# Value in index: 2020-04-23 11:32:49.617000
#
# Value in row: id         pump-1
# value    35.50315
# label           1
# Name: 2020-04-23 11:32:49.617000, dtype: object
#  35.50, 1
#
# Value in index: 2020-04-23 11:32:54.617000
#
# Value in row: id          pump-1
# value    12.338365
# label            0
# Name: 2020-04-23 11:32:54.617000, dtype: object
#  12.34, 0
#
# Value in index: 2020-04-23 11:32:59.618000
#
# Value in row: id          pump-1
# value    10.446508
# label            0
# Name: 2020-04-23 11:32:59.618000, dtype: object
#  10.45, 0
#
# Value in index: 2020-04-23 11:33:04.618000
#
# Value in row: id         pump-1
# value    9.274337
# label           0
# Name: 2020-04-23 11:33:04.618000, dtype: object
#   9.27, 0
#
# Value in index: 2020-04-23 11:33:09.617000
#
# Value in row: id         pump-1
# value    9.784644
# label           0
# Name: 2020-04-23 11:33:09.617000, dtype: object
#   9.78, 0
#
# Value in index: 2020-04-23 11:33:14.617000
#
# Value in row: id          pump-1
# value    11.166963
# label            0
# Name: 2020-04-23 11:33:14.617000, dtype: object
#  11.17, 0
#
# Value in index: 2020-04-23 11:33:19.617000
#
# Value in row: id          pump-1
# value    12.900751
# label            0
# Name: 2020-04-23 11:33:19.617000, dtype: object
#  12.90, 0
#
# Value in index: 2020-04-23 11:33:24.617000
#
# Value in row: id          pump-1
# value    14.176167
# label            0
# Name: 2020-04-23 11:33:24.617000, dtype: object
#  14.18, 0
#
# Value in index: 2020-04-23 11:33:29.617000
#
# Value in row: id          pump-1
# value    15.791453
# label            0
# Name: 2020-04-23 11:33:29.617000, dtype: object
#  15.79, 0
#
# Value in index: 2020-04-23 11:33:34.617000
#
# Value in row: id          pump-1
# value    17.121609
# label            0
# Name: 2020-04-23 11:33:34.617000, dtype: object
#  17.12, 0
#
# Value in index: 2020-04-23 11:33:39.617000
#
# Value in row: id          pump-1
# value    15.335421
# label            0
# Name: 2020-04-23 11:33:39.617000, dtype: object
#  15.34, 0
#
# Value in index: 2020-04-23 11:33:44.617000
#
# Value in row: id          pump-1
# value    14.572203
# label            0
# Name: 2020-04-23 11:33:44.617000, dtype: object
#  14.57, 0
#
# Value in index: 2020-04-23 11:33:49.617000
#
# Value in row: id          pump-1
# value    13.996529
# label            0
# Name: 2020-04-23 11:33:49.617000, dtype: object
#  14.00, 0
#
# Value in index: 2020-04-23 11:33:54.617000
#
# Value in row: id          pump-1
# value    13.289135
# label            0
# Name: 2020-04-23 11:33:54.617000, dtype: object
#  13.29, 0
#
# Value in index: 2020-04-23 11:33:59.617000
#
# Value in row: id          pump-1
# value    12.595558
# label            0
# Name: 2020-04-23 11:33:59.617000, dtype: object
#  12.60, 0
#
# Value in index: 2020-04-23 11:34:04.617000
#
# Value in row: id          pump-1
# value    11.327638
# label            0
# Name: 2020-04-23 11:34:04.617000, dtype: object
#  11.33, 0
#
# Value in index: 2020-04-23 11:34:09.617000
#
# Value in row: id          pump-1
# value    10.196356
# label            0
# Name: 2020-04-23 11:34:09.617000, dtype: object
#  10.20, 0
#
# Value in index: 2020-04-23 11:34:14.617000
#
# Value in row: id        pump-1
# value    8.95525
# label          0
# Name: 2020-04-23 11:34:14.617000, dtype: object
#   8.96, 0
#
# Value in index: 2020-04-23 11:34:19.618000
#
# Value in row: id          pump-1
# value    10.888515
# label            0
# Name: 2020-04-23 11:34:19.618000, dtype: object
#  10.89, 0
#
# Value in index: 2020-04-23 11:34:24.617000
#
# Value in row: id          pump-1
# value    12.131668
# label            0
# Name: 2020-04-23 11:34:24.617000, dtype: object
#  12.13, 0
#
# Value in index: 2020-04-23 11:34:29.617000
#
# Value in row: id          pump-1
# value    13.450141
# label            0
# Name: 2020-04-23 11:34:29.617000, dtype: object
#  13.45, 0
#
# Value in index: 2020-04-23 11:34:34.617000
#
# Value in row: id          pump-1
# value    14.950607
# label            0
# Name: 2020-04-23 11:34:34.617000, dtype: object
#  14.95, 0
#
# Value in index: 2020-04-23 11:34:39.617000
#
# Value in row: id          pump-1
# value    16.016152
# label            0
# Name: 2020-04-23 11:34:39.617000, dtype: object
#  16.02, 0
#
# Value in index: 2020-04-23 11:34:44.618000
#
# Value in row: id         pump-1
# value    16.81646
# label           0
# Name: 2020-04-23 11:34:44.618000, dtype: object
#  16.82, 0
#
# Value in index: 2020-04-23 11:34:49.617000
#
# Value in row: id          pump-1
# value    17.471323
# label            0
# Name: 2020-04-23 11:34:49.617000, dtype: object
#  17.47, 0
#
# Value in index: 2020-04-23 11:34:54.617000
#
# Value in row: id         pump-1
# value    17.29049
# label           0
# Name: 2020-04-23 11:34:54.617000, dtype: object
#  17.29, 0
#
# Value in index: 2020-04-23 11:34:59.617000
#
# Value in row: id          pump-1
# value    16.140599
# label            0
# Name: 2020-04-23 11:34:59.617000, dtype: object
#  16.14, 0
#
# Value in index: 2020-04-23 11:35:04.617000
#
# Value in row: id          pump-1
# value    14.882971
# label            0
# Name: 2020-04-23 11:35:04.617000, dtype: object
#  14.88, 0
#
# Value in index: 2020-04-23 11:35:09.617000
#
# Value in row: id          pump-1
# value    13.481621
# label            0
# Name: 2020-04-23 11:35:09.617000, dtype: object
#  13.48, 0
#
# Value in index: 2020-04-23 11:35:14.617000
#
# Value in row: id          pump-1
# value    12.159489
# label            0
# Name: 2020-04-23 11:35:14.617000, dtype: object
#  12.16, 0
#
# Value in index: 2020-04-23 11:35:19.618000
#
# Value in row: id          pump-1
# value    11.624224
# label            0
# Name: 2020-04-23 11:35:19.618000, dtype: object
#  11.62, 0
#
# Value in index: 2020-04-23 11:35:24.617000
#
# Value in row: id          pump-1
# value    10.607035
# label            0
# Name: 2020-04-23 11:35:24.617000, dtype: object
#  10.61, 0
#
# Value in index: 2020-04-23 11:35:29.617000
#
# Value in row: id          pump-1
# value    10.224724
# label            0
# Name: 2020-04-23 11:35:29.617000, dtype: object
#  10.22, 0
#
# Value in index: 2020-04-23 11:35:34.617000
#
# Value in row: id         pump-1
# value    8.410759
# label           0
# Name: 2020-04-23 11:35:34.617000, dtype: object
#   8.41, 0
#
# Value in index: 2020-04-23 11:35:39.617000
#
# Value in row: id         pump-1
# value    8.760434
# label           0
# Name: 2020-04-23 11:35:39.617000, dtype: object
#   8.76, 0
#
# Value in index: 2020-04-23 11:35:44.617000
#
# Value in row: id         pump-1
# value    9.509002
# label           0
# Name: 2020-04-23 11:35:44.617000, dtype: object
#   9.51, 0
#
# Value in index: 2020-04-23 11:35:49.617000
#
# Value in row: id          pump-1
# value    10.547324
# label            0
# Name: 2020-04-23 11:35:49.617000, dtype: object
#  10.55, 0
#
# Value in index: 2020-04-23 11:35:54.617000
#
# Value in row: id          pump-1
# value    11.474841
# label            0
# Name: 2020-04-23 11:35:54.617000, dtype: object
#  11.47, 0
#
# Value in index: 2020-04-23 11:35:59.617000
#
# Value in row: id          pump-1
# value    11.618768
# label            0
# Name: 2020-04-23 11:35:59.617000, dtype: object
#  11.62, 0
#
# Value in index: 2020-04-23 11:36:04.617000
#
# Value in row: id          pump-1
# value    12.196916
# label            0
# Name: 2020-04-23 11:36:04.617000, dtype: object
#  12.20, 0
#
# Value in index: 2020-04-23 11:36:09.617000
#
# Value in row: id          pump-1
# value    13.548137
# label            0
# Name: 2020-04-23 11:36:09.617000, dtype: object
#  13.55, 0
#
# Value in index: 2020-04-23 11:36:14.617000
#
# Value in row: id          pump-1
# value    14.709292
# label            0
# Name: 2020-04-23 11:36:14.617000, dtype: object
#  14.71, 0
#
# Value in index: 2020-04-23 11:36:19.617000
#
# Value in row: id          pump-1
# value    15.915145
# label            0
# Name: 2020-04-23 11:36:19.617000, dtype: object
#  15.92, 0
#
# Value in index: 2020-04-23 11:36:24.617000
#
# Value in row: id          pump-1
# value    16.619046
# label            0
# Name: 2020-04-23 11:36:24.617000, dtype: object
#  16.62, 0
#
# Value in index: 2020-04-23 11:36:29.618000
#
# Value in row: id          pump-1
# value    18.077273
# label            0
# Name: 2020-04-23 11:36:29.618000, dtype: object
#  18.08, 0
#
# Value in index: 2020-04-23 11:36:34.617000
#
# Value in row: id          pump-1
# value    16.643649
# label            0
# Name: 2020-04-23 11:36:34.617000, dtype: object
#  16.64, 0
#
# Value in index: 2020-04-23 11:36:39.617000
#
# Value in row: id          pump-1
# value    15.490609
# label            0
# Name: 2020-04-23 11:36:39.617000, dtype: object
#  15.49, 0
#
# Value in index: 2020-04-23 11:36:44.617000
#
# Value in row: id          pump-1
# ...
# value    17.815255
# label            0
# Name: 2020-04-23 13:12:07.999000, dtype: object
#  17.82, 0
#
# Value in index: 2020-04-23 13:12:12.999000
#
# Value in row: id          pump-2
# value    18.921139
# label            0
# Name: 2020-04-23 13:12:12.999000, dtype: object
#  18.92, 0
#
# Value in index: 2020-04-23 13:12:17.999000
#
# Value in row: id          pump-2
# value    17.510592
# label            0
# Name: 2020-04-23 13:12:17.999000, dtype: object
#  17.51, 0
#
# Value in index: 2020-04-23 13:12:22.999000
#
# Value in row: id         pump-2
# value    17.24515
# label           0
# Name: 2020-04-23 13:12:22.999000, dtype: object
#  17.25, 0
#
# Value in index: 2020-04-23 13:12:27.999000
#
# Value in row: id          pump-2
# value    17.079083
# label            0
# Name: 2020-04-23 13:12:27.999000, dtype: object
#  17.08, 0
#
# Value in index: 2020-04-23 13:12:32.999000
#
# Value in row: id          pump-2
# value    16.454588
# label            0
# Name: 2020-04-23 13:12:32.999000, dtype: object
#  16.45, 0
#
# Value in index: 2020-04-23 13:12:37.999000
#
# Value in row: id          pump-2
# value    14.949497
# label            0
# Name: 2020-04-23 13:12:37.999000, dtype: object
#  14.95, 0
#
# Value in index: 2020-04-23 13:12:42.999000
#
# Value in row: id          pump-2
# value    13.009512
# label            0
# Name: 2020-04-23 13:12:42.999000, dtype: object
#  13.01, 0
#
# Value in index: 2020-04-23 13:12:47.999000
#
# Value in row: id          pump-2
# value    12.138042
# label            0
# Name: 2020-04-23 13:12:47.999000, dtype: object
#  12.14, 0
#
# Value in index: 2020-04-23 13:12:53.045000
#
# Value in row: id          pump-2
# value    10.871929
# label            0
# Name: 2020-04-23 13:12:53.045000, dtype: object
#  10.87, 0
#
# Value in index: 2020-04-23 13:12:57.999000
#
# Value in row: id         pump-2
# value    27.02801
# label           1
# Name: 2020-04-23 13:12:57.999000, dtype: object
#  27.03, 1
#
# Value in index: 2020-04-23 13:13:02.999000
#
# Value in row: id         pump-2
# value    9.232535
# label           0
# Name: 2020-04-23 13:13:02.999000, dtype: object
#   9.23, 0
#
# Value in index: 2020-04-23 13:13:07.999000
#
# Value in row: id          pump-2
# value    10.320667
# label            0
# Name: 2020-04-23 13:13:07.999000, dtype: object
#  10.32, 0
#
# Value in index: 2020-04-23 13:13:12.999000
#
# Value in row: id          pump-2
# value    10.442719
# label            0
# Name: 2020-04-23 13:13:12.999000, dtype: object
#  10.44, 0
#
# Value in index: 2020-04-23 13:13:17.999000
#
# Value in row: id          pump-2
# value    12.397171
# label            0
# Name: 2020-04-23 13:13:17.999000, dtype: object
#  12.40, 0
#
# Value in index: 2020-04-23 13:13:22.999000
#
# Value in row: id          pump-2
# value    12.922671
# label            0
# Name: 2020-04-23 13:13:22.999000, dtype: object
#  12.92, 0
#
# Value in index: 2020-04-23 13:13:27.999000
#
# Value in row: id          pump-2
# value    14.914278
# label            0
# Name: 2020-04-23 13:13:27.999000, dtype: object
#  14.91, 0
#
# Value in index: 2020-04-23 13:13:32.999000
#
# Value in row: id          pump-2
# value    16.414086
# label            0
# Name: 2020-04-23 13:13:32.999000, dtype: object
#  16.41, 0
#
# Value in index: 2020-04-23 13:13:37.999000
#
# Value in row: id          pump-2
# value    17.448772
# label            0
# Name: 2020-04-23 13:13:37.999000, dtype: object
#  17.45, 0
#
# Value in index: 2020-04-23 13:13:42.999000
#
# Value in row: id          pump-2
# value    17.767601
# label            0
# Name: 2020-04-23 13:13:42.999000, dtype: object
#  17.77, 0
#
# Value in index: 2020-04-23 13:13:47.999000
#
# Value in row: id          pump-2
# value    18.029687
# label            0
# Name: 2020-04-23 13:13:47.999000, dtype: object
#  18.03, 0
#
# Value in index: 2020-04-23 13:13:52.999000
#
# Value in row: id          pump-2
# value    16.221606
# label            0
# Name: 2020-04-23 13:13:52.999000, dtype: object
#  16.22, 0
#
# Value in index: 2020-04-23 13:13:57.999000
#
# Value in row: id          pump-2
# value    15.613383
# label            0
# Name: 2020-04-23 13:13:57.999000, dtype: object
#  15.61, 0
#
# Value in index: 2020-04-23 13:14:02.999000
#
# Value in row: id          pump-2
# value    14.454367
# label            0
# Name: 2020-04-23 13:14:02.999000, dtype: object
#  14.45, 0
#
# Value in index: 2020-04-23 13:14:07.999000
#
# Value in row: id          pump-2
# value    12.819668
# label            0
# Name: 2020-04-23 13:14:07.999000, dtype: object
#  12.82, 0
#
# Value in index: 2020-04-23 13:14:12.999000
#
# Value in row: id          pump-2
# value    12.249949
# label            0
# Name: 2020-04-23 13:14:12.999000, dtype: object
#  12.25, 0
#
# Value in index: 2020-04-23 13:14:17.999000
#
# Value in row: id          pump-2
# value    12.037562
# label            0
# Name: 2020-04-23 13:14:17.999000, dtype: object
#  12.04, 0
#
# Value in index: 2020-04-23 13:14:22.999000
#
# Value in row: id          pump-2
# value    11.816333
# label            0
# Name: 2020-04-23 13:14:22.999000, dtype: object
#  11.82, 0
#
# Value in index: 2020-04-23 13:14:27.999000
#
# Value in row: id          pump-2
# value    10.079189
# label            0
# Name: 2020-04-23 13:14:27.999000, dtype: object
#  10.08, 0
#
# Value in index: 2020-04-23 13:14:32.999000
#
# Value in row: id        pump-2
# value    9.36684
# label          0
# Name: 2020-04-23 13:14:32.999000, dtype: object
#   9.37, 0
#
# Value in index: 2020-04-23 13:14:37.999000
#
# Value in row: id          pump-2
# value    27.624972
# label            1
# Name: 2020-04-23 13:14:37.999000, dtype: object
#  27.62, 1
#
# Value in index: 2020-04-23 13:14:42.999000
#
# Value in row: id          pump-2
# value    12.704928
# label            0
# Name: 2020-04-23 13:14:42.999000, dtype: object
#  12.70, 0
#
# Value in index: 2020-04-23 13:14:47.999000
#
# Value in row: id          pump-2
# value    13.271382
# label            0
# Name: 2020-04-23 13:14:47.999000, dtype: object
#  13.27, 0
#
# Value in index: 2020-04-23 13:14:52.999000
#
# Value in row: id          pump-2
# value    15.268479
# label            0
# Name: 2020-04-23 13:14:52.999000, dtype: object
#  15.27, 0
#
# Value in index: 2020-04-23 13:14:57.999000
#
# Value in row: id          pump-2
# value    15.830258
# label            0
# Name: 2020-04-23 13:14:57.999000, dtype: object
#  15.83, 0
#
# Value in index: 2020-04-23 13:15:02.999000
#
# Value in row: id       pump-2
# value    16.184
# label         0
# Name: 2020-04-23 13:15:02.999000, dtype: object
#  16.18, 0
#
# Value in index: 2020-04-23 13:15:07.999000
#
# Value in row: id          pump-2
# value    17.462328
# label            0
# Name: 2020-04-23 13:15:07.999000, dtype: object
#  17.46, 0
#
# Value in index: 2020-04-23 13:15:13
#
# Value in row: id         pump-2
# value    18.80299
# label           0
# Name: 2020-04-23 13:15:13, dtype: object
#  18.80, 0
#
# Value in index: 2020-04-23 13:15:17.999000
#
# Value in row: id          pump-2
# value    17.501135
# label            0
# Name: 2020-04-23 13:15:17.999000, dtype: object
#  17.50, 0
#
# Value in index: 2020-04-23 13:15:22.999000
#
# Value in row: id          pump-2
# value    15.913804
# label            0
# Name: 2020-04-23 13:15:22.999000, dtype: object
#  15.91, 0
#
# Value in index: 2020-04-23 13:15:27.999000
#
# Value in row: id          pump-2
# value    14.101841
# label            0
# Name: 2020-04-23 13:15:27.999000, dtype: object
#  14.10, 0
#
# Value in index: 2020-04-23 13:15:32.999000
#
# Value in row: id         pump-2
# value    13.29218
# label           0
# Name: 2020-04-23 13:15:32.999000, dtype: object
#  13.29, 0
#
# Value in index: 2020-04-23 13:15:37.999000
#
# Value in row: id          pump-2
# value    12.110043
# label            0
# Name: 2020-04-23 13:15:37.999000, dtype: object
#  12.11, 0
#
# Value in index: 2020-04-23 13:15:42.999000
#
# Value in row: id          pump-2
# value    11.334087
# label            0
# Name: 2020-04-23 13:15:42.999000, dtype: object
#  11.33, 0
#
# Value in index: 2020-04-23 13:15:47.999000
#
# Value in row: id         pump-2
# value    9.756857
# label           0
# Name: 2020-04-23 13:15:47.999000, dtype: object
#   9.76, 0
#
# Value in index: 2020-04-23 13:15:52.999000
#
# Value in row: id         pump-2
# value    9.901683
# label           0
# Name: 2020-04-23 13:15:52.999000, dtype: object
#   9.90, 0
#
# Value in index: 2020-04-23 13:15:57.999000
#
# Value in row: id          pump-2
# value    11.587308
# label            0
# Name: 2020-04-23 13:15:57.999000, dtype: object
#  11.59, 0
#
# Value in index: 2020-04-23 13:16:02.999000
#
# Value in row: id          pump-2
# value    11.724037
# label            0
# Name: 2020-04-23 13:16:02.999000, dtype: object
#  11.72, 0
#
# Value in index: 2020-04-23 13:16:07.999000
#
# Value in row: id          pump-2
# value    12.471588
# label            0
# Name: 2020-04-23 13:16:07.999000, dtype: object
#  12.47, 0
#
# Value in index: 2020-04-23 13:16:13
#
# Value in row: id          pump-2
# value    12.929548
# label            0
# Name: 2020-04-23 13:16:13, dtype: object
#  12.93, 0
#
# Value in index: 2020-04-23 13:16:17.999000
#
# Value in row: id         pump-2
# value    34.05265
# label           1
# Name: 2020-04-23 13:16:17.999000, dtype: object
#  34.05, 1
#
# Value in index: 2020-04-23 13:16:22.999000
#
# Value in row: id          pump-2
# value    14.545985
# label            0
# Name: 2020-04-23 13:16:22.999000, dtype: object
#  14.55, 0
#
# Value in index: 2020-04-23 13:16:27.999000
#
# Value in row: id          pump-2
# value    15.014957
# label            0
# Name: 2020-04-23 13:16:27.999000, dtype: object
#  15.01, 0
#
# Value in index: 2020-04-23 13:16:32.999000
#
# Value in row: id          pump-2
# value    16.937701
# label            0
# Name: 2020-04-23 13:16:32.999000, dtype: object
#  16.94, 0
#
# Value in index: 2020-04-23 13:16:37.999000
#
# Value in row: id          pump-2
# value    17.405989
# label            0
# Name: 2020-04-23 13:16:37.999000, dtype: object
#  17.41, 0
#
# Value in index: 2020-04-23 13:16:42.999000
#
# Value in row: id          pump-2
# value    18.878314
# label            0
# Name: 2020-04-23 13:16:42.999000, dtype: object
#  18.88, 0
#
# Value in index: 2020-04-23 13:16:47.999000
#
# Value in row: id          pump-2
# value    17.234888
# label            0
# Name: 2020-04-23 13:16:47.999000, dtype: object
#  17.23, 0
#
# Value in index: 2020-04-23 13:16:52.999000
#
# Value in row: id          pump-2
# value    16.202543
# label            0
# Name: 2020-04-23 13:16:52.999000, dtype: object
#  16.20, 0
#
# Value in index: 2020-04-23 13:16:57.999000
#
# Value in row: id          pump-2
# value    15.070931
# label            0
# Name: 2020-04-23 13:16:57.999000, dtype: object
#  15.07, 0
#
# Value in index: 2020-04-23 13:17:02.999000
#
# Value in row: id         pump-2
# value    13.32786
# label           0
# Name: 2020-04-23 13:17:02.999000, dtype: object
#  13.33, 0
#
# Value in index: 2020-04-23 13:17:07.999000
#
# Value in row: id          pump-2
# value    12.722426
# label            0
# Name: 2020-04-23 13:17:07.999000, dtype: object
#  12.72, 0
#
# Value in index: 2020-04-23 13:17:12.999000
#
# Value in row: id         pump-2
# value    11.17905
# label           0
# Name: 2020-04-23 13:17:12.999000, dtype: object
#  11.18, 0
#
# Value in index: 2020-04-23 13:17:17.999000
#
# Value in row: id          pump-2
# value    10.224913
# label            0
# Name: 2020-04-23 13:17:17.999000, dtype: object
#  10.22, 0
#
# Value in index: 2020-04-23 13:17:22.999000
#
# Value in row: id         pump-2
# value    9.243129
# label           0
# Name: 2020-04-23 13:17:22.999000, dtype: object
#   9.24, 0
#
# Value in index: 2020-04-23 13:17:27.999000
#
# Value in row: id          pump-2
# value    10.882023
# label            0
# Name: 2020-04-23 13:17:27.999000, dtype: object
#  10.88, 0
#
# Value in index: 2020-04-23 13:17:32.999000
#
# Value in row: id          pump-2
# value    12.777556
# label            0
# Name: 2020-04-23 13:17:32.999000, dtype: object
#  12.78, 0
#
# Value in index: 2020-04-23 13:17:37.999000
#
# Value in row: id          pump-2
# value    14.743381
# label            0
# Name: 2020-04-23 13:17:37.999000, dtype: object
#  14.74, 0
#
# Value in index: 2020-04-23 13:17:42.999000
#
# Value in row: id          pump-2
# value    14.960815
# label            0
# Name: 2020-04-23 13:17:42.999000, dtype: object
#  14.96, 0
#
# Value in index: 2020-04-23 13:17:47.999000
#
# Value in row: id          pump-2
# value    16.622963
# label            0
# Name: 2020-04-23 13:17:47.999000, dtype: object
#  16.62, 0
#
# Value in index: 2020-04-23 13:17:52.999000
#
# Value in row: id          pump-2
# value    18.342238
# label            0
# Name: 2020-04-23 13:17:52.999000, dtype: object
#  18.34, 0
#
# Value in index: 2020-04-23 13:17:57.999000
#
# Value in row: id          pump-2
# value    45.218748
# label            1
# Name: 2020-04-23 13:17:57.999000, dtype: object
#  45.22, 1
#
# Value in index: 2020-04-23 13:18:02.999000
#
# Value in row: id          pump-2
# value    17.896159
# label            0
# Name: 2020-04-23 13:18:02.999000, dtype: object
#  17.90, 0
#
# Value in index: 2020-04-23 13:18:07.999000
#
# Value in row: id          pump-2
# value    17.235187
# label            0
# Name: 2020-04-23 13:18:07.999000, dtype: object
#  17.24, 0
#
# Value in index: 2020-04-23 13:18:12.999000
#
# Value in row: id         pump-2
# value    16.24763
# label           0
# Name: 2020-04-23 13:18:12.999000, dtype: object
#  16.25, 0
#
# Value in index: 2020-04-23 13:18:17.999000
#
# Value in row: id          pump-2
# value    16.073641
# label            0
# Name: 2020-04-23 13:18:17.999000, dtype: object
#  16.07, 0
#
# Value in index: 2020-04-23 13:18:22.999000
#
# Value in row: id          pump-2
# value    14.333627
# label            0
# Name: 2020-04-23 13:18:22.999000, dtype: object
#  14.33, 0
#
# Value in index: 2020-04-23 13:18:27.999000
#
# Value in row: id          pump-2
# value    13.731626
# label            0
# Name: 2020-04-23 13:18:27.999000, dtype: object
#  13.73, 0
#
# Value in index: 2020-04-23 13:18:32.999000
#
# Value in row: id          pump-2
# value    12.382687
# label            0
# Name: 2020-04-23 13:18:32.999000, dtype: object
#  12.38, 0
#
# Value in index: 2020-04-23 13:18:38.002000
#
# Value in row: id         pump-2
# value    10.92938
# label           0
# Name: 2020-04-23 13:18:38.002000, dtype: object
#  10.93, 0
#
# Value in index: 2020-04-23 13:18:42.999000
#
# Value in row: id         pump-2
# value    9.025419
# label           0
# Name: 2020-04-23 13:18:42.999000, dtype: object
#   9.03, 0
#
# Value in index: 2020-04-23 13:18:47.999000
#
# Value in row: id         pump-2
# value    9.431438
# label           0
# Name: 2020-04-23 13:18:47.999000, dtype: object
#   9.43, 0
#
# Value in index: 2020-04-23 13:18:52.999000
#
# Value in row: id          pump-2
# value    10.135468
# label            0
# Name: 2020-04-23 13:18:52.999000, dtype: object
#  10.14, 0
#
# Value in index: 2020-04-23 13:18:57.999000
#
# Value in row: id          pump-2
# value    12.042551
# label            0
# Name: 2020-04-23 13:18:57.999000, dtype: object
#  12.04, 0
#
# Value in index: 2020-04-23 13:19:02.999000
#
# Value in row: id          pump-2
# value    12.123937
# label            0
# Name: 2020-04-23 13:19:02.999000, dtype: object
#  12.12, 0
#
# Value in index: 2020-04-23 13:19:08.005000
#
# Value in row: id         pump-2
# value    12.80491
# label           0
# Name: 2020-04-23 13:19:08.005000, dtype: object
#  12.80, 0
#
# Value in index: 2020-04-23 13:19:12.999000
#
# Value in row: id          pump-2
# value    14.626118
# label            0
# Name: 2020-04-23 13:19:12.999000, dtype: object
#  14.63, 0
#
# Value in index: 2020-04-23 13:19:17.999000
#
# Value in row: id          pump-2
# value    14.697982
# label            0
# Name: 2020-04-23 13:19:17.999000, dtype: object
#  14.70, 0
#
# Value in index: 2020-04-23 13:19:22.999000
#
# Value in row: id          pump-2
# value    16.386558
# label            0
# Name: 2020-04-23 13:19:22.999000, dtype: object
#  16.39, 0
#
# Value in index: 2020-04-23 13:19:27.999000
#
# Value in row: id          pump-2
# value    17.361092
# label            0
# Name: 2020-04-23 13:19:27.999000, dtype: object
#  17.36, 0
#
# Value in index: 2020-04-23 13:19:32.999000
#
# Value in row: id          pump-2
# value    18.764962
# label            0
# Name: 2020-04-23 13:19:32.999000, dtype: object
#  18.76, 0
#
# Value in index: 2020-04-23 13:19:38
#
# Value in row: id          pump-2
# value    43.276667
# label            1
# Name: 2020-04-23 13:19:38, dtype: object
#  43.28, 1
#
# Value in index: 2020-04-23 13:19:42.999000
#
# Value in row: id          pump-2
# value    16.214949
# label            0
# Name: 2020-04-23 13:19:42.999000, dtype: object
#  16.21, 0
#
# Value in index: 2020-04-23 13:19:47.999000
#
# Value in row: id          pump-2
# value    14.855999
# label            0
# Name: 2020-04-23 13:19:47.999000, dtype: object
#  14.86, 0

# %% [markdown]
# ### Explore the new data format
# Show episodes of the lengh 5 and the label in the last column

# %%
df_epis.tail(5)
# Out:
#              F1         F2         F3         F4         F5  L
# 3009  12.804910  14.626118  14.697982  16.386558  17.361092  0
# 3010  14.626118  14.697982  16.386558  17.361092  18.764962  0
# 3011  14.697982  16.386558  17.361092  18.764962  43.276667  1
# 3012  16.386558  17.361092  18.764962  43.276667  16.214949  0
# 3013  17.361092  18.764962  43.276667  16.214949  14.855999  0

# %% [markdown]
# The data is ready for supervised learning

# %% [markdown]
# ## Prepare the data for modeling, training and testing
# - Identify and separate the feature and target columns
# - Training and Testing Data Split
#
# ### Identify feature and target columns
# Like many ML libraries, sklern requires separted feature (X) and target (Y) columns.

# %%
# Extract feature columns
feature_cols = list(df_epis.columns[:-1])

# Extract target column 'label'
target_col = df_epis.columns[-1] 

# Show the list of columns
print ("Feature columns:\n{}".format(feature_cols))
print ("\nTarget column: {}".format(target_col))

# Separate the data into feature data and target data (X_all and y_all, respectively)
X_all = df_epis[feature_cols]
y_all = df_epis[target_col]

# Show the feature information by printing the first five rows
print ("\nFeature values:")
print (X_all.head())

# %% [markdown]
# ### Training and Testing Data Split
# It is best best practise to have separate sets for the training and test.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split( X_all, y_all, test_size=0.33, random_state=42)


# Show the results of the split
print ("Training set has {} samples.".format(X_train.shape[0]))
print ("Testing set has {} samples.".format(X_test.shape[0]))

print ("Anomaly rate of the training set: {:.2f}%".format(100 * (y_train == 1).mean()))
print ("Anomaly rate of the testing set: {:.2f}%".format(100 * (y_test == 1).mean()))

# %% [markdown]
# ### Model Training
#
# Let's do a quick model training with a Decision Tree Classifier.

# %%
# from sklearn import DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

my_random_seed = 42

# Initialize the DecisionTreeClassifier
model = DecisionTreeClassifier(random_state=my_random_seed)

# train the classifier
model.fit(X_train, y_train)

# Predict with the test data
y_predict = model.predict(X_test)

# Determine the accuracy score
accuracy_score = accuracy_score(y_test, y_predict)

print ("Accuracy score for the trained model: {:.4f}.".format(accuracy_score))

# %% [markdown]
# ... the accuracy is pretty good.
#
#
# ### Save model to disk
# - Save the model
# - Load the model again and check that it works

# %%
from joblib import dump, load

filename = 'model.joblib'
dump(model, open(filename, 'wb'))

# Validate that the model can be loaded

# load the model from disk
loaded_model = load(open(filename, 'rb'))
result = loaded_model.score(X_test, y_test)
print("Score:", result)

# %% [markdown]
# ### Commit the new model to git
# The new model is saved in git so we can use it!
# ```
# git add model.joblib
# git commit -m "Update ML model"
# pit push
# ```
